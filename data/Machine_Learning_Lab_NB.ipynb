# %%
import pandas as pd

df = pd.read_csv('Orders.csv')
print(df)
# Out:
#        Row.ID                  Order.ID Order.Date Ship.Date       Ship.Mode  \
# 0       40098  CA-2014-AB10015140-41954   11/11/14  11/13/14     First Class
# 1       26341    IN-2014-JR162107-41675     2/5/14    2/7/14    Second Class
# 2       25330    IN-2014-CR127307-41929   10/17/14  10/18/14     First Class
# 3       13524   ES-2014-KM1637548-41667    1/28/14   1/30/14     First Class
# 4       47221   SG-2014-RH9495111-41948    11/5/14   11/6/14        Same Day
# 5       22732    IN-2014-JM156557-41818    6/28/14    7/1/14    Second Class
# 6       30570   IN-2012-TS2134092-41219    11/6/12   11/8/12     First Class
# 7       31192   IN-2013-MB1808592-41378    4/14/13   4/18/13  Standard Class
# 8       40099  CA-2014-AB10015140-41954   11/11/14  11/13/14     First Class
# 9       36258  CA-2012-AB10015140-40974     3/6/12    3/7/12     First Class
# 10      36259  CA-2012-AB10015140-40974     3/6/12    3/7/12     First Class
# ...

# %%
df[['Profit','Sales']]
# Out:
#           Profit      Sales
# 0         $62.15    $221.98
# 1       -$288.77  $3,709.40
# 2        $919.97  $5,175.17
# 3        -$96.54  $2,892.51
# 4        $311.52  $2,832.96
# 5        $763.28  $2,862.68
# 6        $564.84  $1,822.08
# 7        $996.48  $5,244.84
# 8         $54.71    $341.96
# 9          $5.48     $48.71
# 10         $4.66     $17.94
# 11       $647.55  $4,626.15
# 12     $1,151.40  $2,616.96
# 13       $622.02  $2,221.80
# 14     $1,036.08  $3,701.52
# 15       $186.95  $1,869.59
# 16        -$2.52     $12.62
# 17     $3,979.08  $7,958.58
# 18        $28.40  $2,565.59
# 19       $818.28  $3,409.74
# 20       $276.84  $1,977.72
# 21         $4.86    $242.94
# 22       $358.02  $2,754.00
# 23     $1,898.40  $5,273.70
# 24       $445.52  $1,713.84
# 25       $526.50  $2,106.50
# 26       $720.36  $1,715.16
# 27     $1,364.24  $3,069.74
# 28       $121.44    $247.84
# 29       $582.36  $1,878.72
# ...          ...        ...
# 51260     -$1.11      $0.44
# ...

# %%
df['Profit'] = [int(x.replace('$', '')) for x in df['Profit']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-9eb6e3c1d899> in <module>
# ----> 1 df['Profit'] = [int(x.replace('$', '')) for x in df['Profit']]
#
# <ipython-input-26-9eb6e3c1d899> in <listcomp>(.0)
# ----> 1 df['Profit'] = [int(x.replace('$', '')) for x in df['Profit']]
#
# ValueError: invalid literal for int() with base 10: '62.15'

# %%
df['Profit'] = [x.strip('$') for x in float(df['Profit'])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-0de993387ac6> in <module>
# ----> 1 df['Profit'] = [x.strip('$') for x in float(df['Profit'])]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'float'>
